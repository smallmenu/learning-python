# %%
peoples = []
peoples.append({
    # "ulzzang-6500-v1.1:1":"",
    "8k,RAW photo,best quality,masterpiece:1.2": "8k",
    "realistic,photorealistic:1.4": "逼真",
    "film grain:1.2":"胶片颗粒",
    "soft focus:1.4" : "柔焦",
    "sharp focus:1.4" : "锐焦",
    "ultra high res": "高分辨率",
    "ultra detailed": "超详细",
    "detailed skin": "细致的皮肤",
    "detailed beautiful face": "精致美丽的脸",
    "detailed beautiful eyes:1.2": "精致美丽的眼睛",
    "realistic face": "真实的脸",
    "realistic skin": "真实的皮肤",
    "realistic eyes:1.2": "真实的眼睛",
    "cinematic lighting": "电影灯光",
}) 
peoples.append({
    "looking at viewer": "面向观察者",
    # "back view":"",
    # "from behind":"",
    # "dating": "约会",
    # "night:1.2":"",
    # "rain":"",
    # "cyber":""
    "cityscape":"城市景观"
})
peoples.append({
    "1 girl": "",
    "1 woman": "",
    "solo" : "solo",
    "slim girl": "苗条",
    "small breasts": "小胸",
    "simle": "微笑",
    "cute": "可爱",
    "thin waist":"",
    "happy": "",
    "brown hair:1.1": "头发",
    "floating hair":"",
    "full-body": "全身",
    "22 years old":"年龄",
    # "makeup": "妆容",
})
peoples.append({
    # "collared shirt:1.2": "有领衬衫",
    # "skirt:1.2": "短裙",
    # "dress:1.2": "连衣裙",
    "pleated skirt": "短裙",
    "collared shirt": "衬衫",
    # "black transparent stockings:1.2": "丝袜",
})
peoples.append({
    "detailed street:1.1": "",
    "detailed sky:1.1": "",
})
peoples.append({
    # "sitting": "",
    "standing on the street:1.2": "",
})

negative = {
    
    "worst quality:2": "最差质量",
    "low quality:2": "低质量",
    "normal quality:2": "正常质量",
    "ugly:2":"丑陋的",
    "unclear eyes:1.5": "眼睛不清晰",
    "bad anatomy:1.33": "解剖学不好",
    "bad hands:1.33": "坏手",
    "extra fingers:1.33": "额外的手指",
    "extra arms:1.33":"额外的手臂",
    "mutated hands:1.33":"变异的手",
    "fused fingers:1.33":"融合的手指",
    "too many fingers:1.33": "太多的手指",
    "weird hands:1.33" : "诡异的手", 
    "broken fingers:1.33" : "破坏的手指",
    "missing fingers:1.33":"缺失的手指",
    "extra limbs:1.33": "多余的肢体",
    "extra legs:1.33":"额外的腿",
    "distorted face:1.33": "扭曲的脸",
    
    "disfigured:1.33": "毁容",
    "duplicate:1.33": "重复",
    "monochrome:1.21": "单色",
    "grayscale:1.21": "灰度",
    "bad feet:1.21":"坏脚",
    "morbid:1.21": "病态",
    "mutilated:1.21": "病态",
    "poorly drawn hands": "画的不好的手",
    "poorly drawn face": "画的不好的脸",
    "poorly drawn eyes": "画的不好的眼睛",
    "poorly drawn fingers": "画的不好的手指",
    "poorly drawn feet": "画的不好的脚",
    "big head": "大头",
    "long neck": "长脖子",
    "sketches" : "素描",
    "paintings": "绘画",
    "naked": "裸体",
    "tiling": "平铺",
    "skin spots": "皮肤瑕疵",
    
    "skin blemishes": "皮肤瑕疵",
    "out of frame": "画框外",
    "deformed": "变形",
    "body out of frame": "身体框架外",
    "watermark": "水印",
    "signature": "签名",
    "cut off": "切断",
    "low contrast": "低对比度",
    "underexposed": "曝光不足",
    "overexposed": "曝光过度",
    "bad art": "不好艺术",
    "beginner": "初学者",
    "amateur": "业余爱好者",
    "blurry": "模糊",
    "draft": "草稿",
    "grainy": "颗粒状",
    "blurry": "模糊",
    "pubic hair":"",
    "glans":"",
    "username":"",
    "EasyNegative":"",
    "NG_DeepNegative_V1_75T":"",
}

for people in peoples:
    for key, value in people.items():
        if ':' in key :
            print('({0}),'.format(key), end='')
        else :
            print('{0},'.format(key), end='')

print('')
for key, value in negative.items():
        if ':' in key :
            print('({0}),'.format(key), end='')
        else :
            print('{0},'.format(key), end='')
# Out:
# (8k,RAW photo,best quality,masterpiece:1.2),(realistic,photorealistic:1.4),(film grain:1.2),(soft focus:1.4),(sharp focus:1.4),ultra high res,ultra detailed,detailed skin,detailed beautiful face,(detailed beautiful eyes:1.2),realistic face,realistic skin,(realistic eyes:1.2),cinematic lighting,looking at viewer,cityscape,1 girl,1 woman,solo,slim girl,small breasts,simle,cute,thin waist,happy,(brown hair:1.1),floating hair,full-body,22 years old,pleated skirt,collared shirt,(detailed street:1.1),(detailed sky:1.1),(standing on the street:1.2),
# (worst quality:2),(low quality:2),(normal quality:2),(ugly:2),(unclear eyes:1.5),(bad anatomy:1.33),(bad hands:1.33),(extra fingers:1.33),(extra arms:1.33),(mutated hands:1.33),(fused fingers:1.33),(too many fingers:1.33),(weird hands:1.33),(broken fingers:1.33),(missing fingers:1.33),(extra limbs:1.33),(extra legs:1.33),(distorted face:1.33),(disfigured:1.33),(duplicate:1.33),(monochrome:1.21),(grayscale:1.21),(bad feet:1.21),(morbid:1.21),(mutilated:1.21),poorly drawn hands,poorly drawn face,poorly drawn eyes,poorly drawn fingers,poorly drawn feet,big head,long neck,sketches,paintings,naked,tiling,skin spots,skin blemishes,out of frame,deformed,body out of frame,watermark,signature,cut off,low contrast,underexposed,overexposed,bad art,beginner,amateur,blurry,draft,grainy,pubic hair,glans,username,EasyNegative,NG_DeepNegative_V1_75T,
