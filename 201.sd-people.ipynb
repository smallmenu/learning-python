# %%
peoples = []
peoples.append({
    "ulzzang-6500-v1.1:1":"",
    "8k,RAW photo,best quality,masterpiece:1.2": "8k",
    "photorealistic:1.4": "逼真",
    "film grain:1.4":"胶片颗粒",
    "soft focus:1.4" : "柔焦",
    "sharp focus:1.4" : "锐焦",
    "ultra high res": "高分辨率",
    "ultra detailed": "超详细",
    "stunningly beautiful": "惊人的美丽",
    "detailed skin": "细致的皮肤",
    "detailed beautiful face": "精致美丽的脸",
    "detailed beautiful eyes": "精致美丽的眼睛",
    "realistic face": "真实的脸",
    "realistic skin": "真实的皮肤",
    "realistic eyes": "真实的眼睛",
    "cinematic lighting": "电影灯光",
}) 
peoples.append({
    "looking at viewer": "面向观察者",
    # "back view":"",
    "from behind":"",
    # "dating": "约会",
    # "night:1.2":"",
    # "rain":"",
    # "cyber":""
    "cityscape":"城市景观"
})
peoples.append({
    "1 girl": "",
    "1 woman": "",
    "solo" : "solo",
    "slim girl": "苗条",
    "small breasts": "小胸",
    "simle": "微笑",
    "cute": "可爱",
    "thin waist":"",
    "happy": "",
    "brown hair:1.1": "头发",
    "floating hair":"",
    "full-body": "全身",
    "22 years old":"年龄",
    # "makeup": "妆容",
})
peoples.append({
    # "collared shirt:1.2": "有领衬衫",
    # "skirt:1.2": "短裙",
    "dress:1.2": "连衣裙",
    # "black transparent stockings:1.2": "丝袜",
})
peoples.append({
    "detailed street:1.1": "",
    "detailed sky:1.1": "",
})
peoples.append({
    # "sitting": "",
    "standing on the street:1.2": "",
})

negative = {
    "worst quality:2": "最差质量",
    "low quality:2": "低质量",
    "normal quality:2": "正常质量",
    "ugly:2":"丑陋的",
    "bad anatomy:2": "解剖学不好",
    "bad hands:2": "坏手",
    "extra fingers:2": "额外的手指",
    "extra arms:2":"额外的手臂",
    "mutated hands:2":"变异的手",
    "fused fingers:2":"融合的手指",
    "too many fingers:2": "太多的手指",
    "poorly drawn fingers:2": "画的不好的手指",
    "weird hands:2" : "诡异的手", 
    "broken fingers:2" : "破坏的手指",
    "missing fingers:2":"缺失的手指",
    "extra limbs:2": "多余的肢体",
    "extra legs:2":"额外的腿",
    "poorly drawn feet:1.5": "画的不好的脚",
    "bad feet:1.5":"坏脚",
    "poorly drawn hands:1.5": "画的不好的手",
    "poorly drawn face:1.5": "画的不好的脸",
    "poorly drawn eyes:1.5": "画的不好的眼睛",
    "distorted face:1.5": "扭曲的脸",
    "disfigured:1.5": "毁容",
    "monoch rome:1.2": "单色",
    "grayscale:1.2": "灰度",
    "big head:1.2": "大头",
    "long neck:1.1": "长脖子",
    "sketches" : "素描",
    "paintings": "绘画",
    "naked": "裸体",
    "tiling": "平铺",
    "skin blemishes": "皮肤瑕疵",
    "out of frame": "画框外",
    "deformed": "变形",
    "body out of frame": "身体框架外",
    "watermark": "水印",
    "signature": "签名",
    "cut off": "切断",
    "low contrast": "低对比度",
    "underexposed": "曝光不足",
    "overexposed": "曝光过度",
    "bad art": "不好艺术",
    "beginner": "初学者",
    "amateur": "业余爱好者",
    "blurry": "模糊",
    "draft": "草稿",
    "grainy": "颗粒状"
}

for people in peoples:
    for key, value in people.items():
        if ':' in key :
            print('({0}),'.format(key), end='')
        else :
            print('{0},'.format(key), end='')

print('')
for key, value in negative.items():
        if ':' in key :
            print('({0}),'.format(key), end='')
        else :
            print('{0},'.format(key), end='')
# Out:
# ulzzang-6500-v1.1,(8k,RAW photo,best quality,masterpiece:1.2),(photorealistic:1.4),(film grain:1.4),(soft focus:1.4),(sharp focus:1.4),ultra high res,ultra detailed,stunningly beautiful,detailed skin,detailed beautiful face,detailed beautiful eyes,realistic face,realistic skin,realistic eyes,cinematic lighting,back to viewer,back view,from behind,cityscape,1 girl,1 woman,solo,slim girl,small breasts,simle,cute,thin waist,happy,(brown hair:1.1),floating hair,full-body,22 years old,(dress:1.2),(detailed street:1.1),(detailed sky:1.1),(standing on the street:1.2),
# ...
