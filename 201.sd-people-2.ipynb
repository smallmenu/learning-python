# %%
peoples = []
peoples.append({
    "8k,RAW photo,best quality,masterpiece:1.2": "8k",
    "realistic,photorealistic:1.4": "逼真",
    "film grain:1.2":"胶片颗粒",
    "soft focus:1.4" : "柔焦",
    "sharp focus:1.4" : "锐焦",
    "ultra high res": "高分辨率",
    "ultra detailed": "超详细",
    "detailed skin": "细致的皮肤",
    "detailed beautiful face": "精致美丽的脸",
    "detailed beautiful eyes:1.2": "精致美丽的眼睛",
    "realistic face": "真实的脸",
    "realistic skin": "真实的皮肤",
    "realistic eyes:1.2": "真实的眼睛",
    "cinematic lighting": "电影灯光",
}) 
peoples.append({
    "looking at viewer": "面向观察者",
    # "back view":"",
    # "from behind":"",
    "dating": "约会",
    # "rain":"",
    # "cyber":""
    "cityscape":"城市景观",
    # "outdoors":"城市景观"
})
peoples.append({
    "1 girl": "",
    "solo" : "solo",
    "slim girl": "苗条",
    "small breasts": "小胸",
    "laughing": "笑",
    "cute": "可爱",
    "thin waist":"瘦腰",
    "floating hair":"头发",
    "full-body": "全身",
    "22 years old":"年龄",
})
peoples.append({
    # "collared shirt:1.2": "有领衬衫",
    "pattern skirt": "花纹短裙",
    "t-shirt": "衬衫",
    # "black transparent stockings:1.1": "丝袜",
})
peoples.append({
    "detailed sky:1.1": "",
    "detailed street:1.1": "",
})
peoples.append({
    # "sitting": "",
    "standing on the street:1.1": "",
})

negative = {
    "worst quality:2": "最差质量",
    "low quality:2": "低质量",
    "normal quality:2": "正常质量",
    "lowres":"低分辨率",

    "ugly:1.33":"丑陋的",
    "blurry": "模糊的",
    "duplicate:1.33": "重复的",
    "disgusting":"恶心",
    "morbid:1.21": "病态的",
    "mutilated:1.21": "残缺的",
    "tranny:1.33": "变性的",
    "naked:1.21": "裸体",

    "poorly drawn face": "画的不好的脸",
    "poorly drawn eyes": "画的不好的眼睛",
    "poorly drawn hands:1.33": "画的不好的手",
    "poorly drawn fingers": "画的不好的手指",
    "poorly drawn feet": "画的不好的脚",
    
    "missing limb":"缺少肢体",
    "disconnected limbs":"断开的肢体",
    "floating limbs":"浮动的肢体", 
    "extra limbs": "多余的肢体",

    "malformed hands":"畸形的手",
    "extra fingers": "多余的手",
    "mutated hands and fingers":"变异的手",
    "extra arms":"多余的手臂",
    "fused fingers:1.61":"融合的手指",
    "too many fingers:1.61": "太多的手指",
    "extra legs":"额外的腿",
    "strange fingers":"",
    
    "bad anatomy:1.21": "不好的解剖学",
    "bad hands": "不好的手",
    "bad proportions": "不好的比例",
    "bad boyd": "不好的身体",
    "bad feet":"不好的脚",

    "mutated hands":"变异的手",
    "weird hands" : "诡异的手", 
    "broken fingers" : "破坏的手指",
    "missing fingers":"缺失的手指",

    "skin blemishes": "皮肤",
    "acnes": "皮肤",
    "age spot": "皮肤",
    
    "distorted face": "扭曲的脸",
    "disfigured": "毁容",
    "unclear eyes:1.33": "眼睛不清晰",

    "more than 2 nipples:1.33": "多余2个",
    "big head": "大头",
    "long neck": "长脖子",
    "pubic hair":"",
    "glans":"",

    "outdool:1.6":"",
    "manboobs":"",
    "futa:1.1":"",

    "backlight":"背光",
    "monoch rome:1.21": "单色",
    "grayscale:1.21": "灰度",
    "sketches" : "素描",
    "paintings": "绘画",
    "tiling": "平铺",
    "deformed": "变形",
    "watermark": "水印",
    "signature": "签名",
    # "beginner": "初学者",
    # "amateur": "业余爱好者",
    # "draft": "草稿",
    # "grainy": "颗粒状"
    "EasyNegative":"",
    "NG_DeepNegative_V1_75T":"",
}

for people in peoples:
    for key, value in people.items():
        if ':' in key :
            print('({0}),'.format(key), end='')
        else :
            print('{0},'.format(key), end='')

print('')
for key, value in negative.items():
        if ':' in key :
            print('({0}),'.format(key), end='')
        else :
            print('{0},'.format(key), end='')
# Out:
# (8k,RAW photo,best quality,masterpiece:1.2),(realistic,photorealistic:1.4),(film grain:1.2),(soft focus:1.4),(sharp focus:1.4),ultra high res,ultra detailed,detailed skin,detailed beautiful face,(detailed beautiful eyes:1.2),realistic face,realistic skin,(realistic eyes:1.2),cinematic lighting,looking at viewer,dating,cityscape,1 girl,solo,slim girl,small breasts,laughing,cute,thin waist,floating hair,full-body,22 years old,pattern skirt,t-shirt,(detailed sky:1.1),(detailed street:1.1),(standing on the street:1.1),
# ...
